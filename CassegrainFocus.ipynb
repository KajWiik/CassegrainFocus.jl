# %%
subr = readdlm("profile_meas/subrefl-profile-meas.txt")
# Out:
# 75×2 Array{Float64,2}:
#   30.0    7.4
#   35.0    8.665
#   40.0   10.025
#   45.0   11.475
#   50.0   13.035
#   55.0   14.685
#   60.0   16.455
#   65.0   18.255
#   70.0   20.18
#   75.0   22.185
#   80.0   24.235
#   85.0   26.345
#   90.0   28.53
#    ⋮
#  345.0  155.11
#  350.0  157.4
#  355.0  159.66
#  360.0  161.93
#  365.0  164.155
#  370.0  166.365
#  375.0  168.55
#  380.0  170.72
#  385.0  172.885
#  390.0  174.985
#  395.0  177.045
#  400.0  179.105

# %%
using Plots

# %%
x = vcat(-subr[end:-1:1,1],subr[:,1]);z = vcat(subr[end:-1:1,2],subr[:,2]);

# %%
plot(x/10,z+1520)
# Out:
# <img src="data:image/png;base64,..." />
